# %% [markdown]
# # Week 3: Logistics Performance & Cost Driver Analysis
# **Author:** Data Analysis Team
# **Date:** August 2026
# **Objective:** Perform Exploratory Data Analysis (EDA) on a 250-shipment logistics dataset to analyze delivery performance, cost drivers, and operational bottlenecks.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_theme(style='whitegrid')

# %% [markdown]
# ## 1. Load Data & Summary Statistics

# %%
df = pd.read_csv('logistics_data.csv')
df.head()

# %%
print('Missing Values:\n', df.isnull().sum())
df_clean = df.copy()
df_clean['fuel_cost_inr'].fillna(df_clean['fuel_cost_inr'].median(), inplace=True)
df_clean['delivery_time_days'].fillna(df_clean['delivery_time_days'].median(), inplace=True)
df_clean.describe().T[['mean', '50%', 'std', 'min', 'max']]

# %% [markdown]
# ## 2. Correlation Analysis & Visualizations

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='transport_mode', y='transport_cost_inr', data=df_clean, palette='Set2')
plt.title('Transportation Cost (INR) by Mode')
plt.show()
